# %%
# ============================================================
# Autosave helpers for Quad4FHE plaintext experiments
# - duplicates notebook stdout/stderr to a .txt log
# - writes structured JSON after each quad4fhe.replace(...) run
# - writes a compact CSV summary
# ============================================================
from __future__ import annotations

import contextlib
import json
import math
import re
import sys
import traceback
from datetime import datetime
from pathlib import Path
from typing import Any, Dict, Iterable, Optional


_AUTOSAVE_PAYLOAD: Optional[Dict[str, Any]] = None
_AUTOSAVE_RUNS = []
_AUTOSAVE_SUMMARY_ROWS = []


class _AutosaveTeeStream:
    def __init__(self, *streams):
        self.streams = streams

    def write(self, data):
        for stream in self.streams:
            stream.write(data)
            stream.flush()

    def flush(self):
        for stream in self.streams:
            stream.flush()

    def isatty(self):
        return any(getattr(stream, "isatty", lambda: False)() for stream in self.streams)


@contextlib.contextmanager
def tee_stdout_stderr(log_path):
    log_path = Path(log_path)
    log_path.parent.mkdir(parents=True, exist_ok=True)
    old_stdout, old_stderr = sys.stdout, sys.stderr
    with log_path.open("w", encoding="utf-8", buffering=1) as fh:
        sys.stdout = _AutosaveTeeStream(old_stdout, fh)
        sys.stderr = _AutosaveTeeStream(old_stderr, fh)
        try:
            print(f"[autosave] stdout/stderr log -> {log_path}")
            yield log_path
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr


def _to_jsonable(obj: Any) -> Any:
    try:
        import numpy as _np
    except Exception:
        _np = None
    try:
        import pandas as _pd
    except Exception:
        _pd = None
    try:
        import torch as _torch
    except Exception:
        _torch = None

    if obj is None or isinstance(obj, (str, bool, int)):
        return obj
    if isinstance(obj, float):
        return obj if math.isfinite(obj) else None
    if _np is not None:
        if isinstance(obj, _np.integer):
            return int(obj)
        if isinstance(obj, _np.floating):
            value = float(obj)
            return value if math.isfinite(value) else None
        if isinstance(obj, _np.bool_):
            return bool(obj)
        if isinstance(obj, _np.ndarray):
            return _to_jsonable(obj.tolist())
    if _torch is not None and hasattr(_torch, "is_tensor") and _torch.is_tensor(obj):
        return _to_jsonable(obj.detach().cpu().numpy())
    if isinstance(obj, Path):
        return str(obj)
    if _pd is not None:
        if isinstance(obj, _pd.DataFrame):
            return _to_jsonable(obj.to_dict(orient="records"))
        if isinstance(obj, _pd.Series):
            return _to_jsonable(obj.to_dict())
    if isinstance(obj, dict):
        return {str(k): _to_jsonable(v) for k, v in obj.items()}
    if isinstance(obj, (list, tuple, set)):
        return [_to_jsonable(v) for v in obj]
    return str(obj)


def _save_json(obj: Dict[str, Any], path) -> Path:
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("w", encoding="utf-8") as fh:
        json.dump(_to_jsonable(obj), fh, indent=2, ensure_ascii=False, allow_nan=False)
    print(f"[autosave] JSON -> {path}")
    return path


def _save_csv(rows: Iterable[Dict[str, Any]], path) -> Path:
    import pandas as _pd
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    _pd.DataFrame(list(rows)).to_csv(path, index=False)
    print(f"[autosave] CSV -> {path}")
    return path


def _dataframe_records(df: Any) -> list:
    if df is None:
        return []
    try:
        return _to_jsonable(df.to_dict(orient="records"))
    except Exception:
        return []


def _dataframe_test_by_method(df: Any) -> Dict[str, Dict[str, Any]]:
    out: Dict[str, Dict[str, Any]] = {}
    if df is None:
        return out
    try:
        sub = df[df["Split"] == "test"]
        for _, row in sub.iterrows():
            method = str(row.get("Method"))
            metrics = {str(k): _to_jsonable(v) for k, v in row.to_dict().items()
                       if k not in ("Method", "Split")}
            out[method] = metrics
    except Exception:
        return out
    return out


def _metric_from_table(table: Dict[str, Dict[str, Any]], method: str, *keys: str) -> Any:
    row = table.get(method, {})
    for key in keys:
        if key in row:
            return row[key]
    return None


def _quad_report_diagnostics(result: Any, split: str, n_expected: Optional[int] = None) -> Dict[str, Any]:
    if split in ("fit", "calib", "calibration"):
        attr_candidates = ["fit_diagnostics", "calib_diagnostics", "calibration_diagnostics"]
        split_label = "fit"
    else:
        attr_candidates = ["test_diagnostics"]
        split_label = "test"

    diag = None
    for attr in attr_candidates:
        value = getattr(result, attr, None)
        if value is not None:
            diag = dict(value)
            break

    if diag is None:
        diag = {}
        df = getattr(result, "report_vs_pseudo", None)
        if df is not None:
            try:
                row = df[(df["Method"] == "Quad4FHE") & (df["Split"] == split_label)]
                if len(row) > 0:
                    diag["agreement"] = float(row.iloc[0]["Agreement"])
            except Exception:
                pass

    n_value = diag.get("n", diag.get("calib_n", diag.get("n_samples", n_expected)))
    agreement = diag.get("agreement", diag.get("calib_agreement", diag.get("fit_agreement")))
    mismatch = diag.get("mismatch_count", diag.get("calib_mismatch_count", diag.get("fit_mismatch_count")))
    if mismatch is None and agreement is not None and n_value is not None:
        mismatch = int(round((1.0 - float(agreement)) * int(n_value)))

    exact = diag.get("exact_preserved", diag.get("exact_preserved_on_calib", diag.get("fit_exact_preserved")))
    if exact is None and mismatch is not None:
        exact = bool(int(mismatch) == 0)

    return {
        "split": split_label,
        "n": _to_jsonable(n_value),
        "agreement": _to_jsonable(agreement),
        "mismatch_count": _to_jsonable(mismatch),
        "exact_preserved": _to_jsonable(exact),
    }


def _quad_solver_diagnostics(result: Any) -> Dict[str, Any]:
    return _to_jsonable(dict(getattr(result, "solver_diagnostics", None) or {}))


def _build_quad4fhe_run_record(
    *,
    result: Any,
    key: str,
    hidden_dim: Optional[int],
    fit_n: Optional[int],
    test_n: Optional[int],
    pool_fraction: Optional[float] = None,
    rep_fit_size: Optional[int] = None,
    extra: Optional[Dict[str, Any]] = None,
) -> Dict[str, Any]:
    fit_diag = _quad_report_diagnostics(result, "fit", n_expected=fit_n)
    test_diag = _quad_report_diagnostics(result, "test", n_expected=test_n)
    solver_diag = _quad_solver_diagnostics(result)

    report_truth_test = _dataframe_test_by_method(getattr(result, "report_vs_truth", None))
    report_pseudo_test = _dataframe_test_by_method(getattr(result, "report_vs_pseudo", None))

    calib_agreement = fit_diag.get("agreement")
    test_agreement = test_diag.get("agreement")
    gap = None
    if calib_agreement is not None and test_agreement is not None:
        gap = float(calib_agreement) - float(test_agreement)

    constraint_version = getattr(result, "constraint_version", None)
    if constraint_version is None:
        constraint_version = solver_diag.get("constraint_version")

    common_solver_keys = [
        "num_pairwise_constraints",
        "min_pairwise_margin",
        "normalized_min_pairwise_margin",
        "slack_positive_count",
        "sum_slack",
        "mean_slack",
        "max_slack",
        "pairwise_slack_positive_count",
        "pairwise_sum_slack",
        "pairwise_mean_slack",
        "pairwise_max_slack",
        "selected_C",
        "soft_C_grid",
        "soft_trace",
        "selected_mu",
        "mu_grid",
        "mu_p",
        "mu_n",
    ]

    quad = {
        "alpha": getattr(result, "alpha", None),
        "beta": getattr(result, "beta", None),
        "eta": getattr(result, "eta", None),
        "threshold": getattr(result, "threshold", None),
        "zero_threshold_realized": getattr(result, "zero_threshold_realized", None),
        "method_used": getattr(result, "method_used", None),
        "hard_feasible": getattr(result, "feasible", None),
        "empirical_margin": getattr(result, "empirical_margin", None),
        "normalized_margin": getattr(result, "normalized_margin", None),
        "quant_decimals": getattr(result, "quant_decimals", None),
        "constraint_version": constraint_version,
        "he_artifact_dir": str(getattr(result, "he_export_dir", None)) if getattr(result, "he_export_dir", None) else None,
        "calib_n": fit_diag.get("n"),
        "calib_agreement": calib_agreement,
        "calib_mismatch_count": fit_diag.get("mismatch_count"),
        "exact_preserved_on_calib": fit_diag.get("exact_preserved"),
        "test_n": test_diag.get("n"),
        "test_agreement": test_agreement,
        "test_mismatch_count": test_diag.get("mismatch_count"),
        "calib_test_agreement_gap": gap,
        "test_top1_acc": _metric_from_table(report_truth_test, "Quad4FHE", "ACC", "Top1", "Top-1"),
        "test_top5_acc": _metric_from_table(report_truth_test, "Quad4FHE", "Top5", "Top-5"),
        "test_macro_f1": _metric_from_table(report_truth_test, "Quad4FHE", "MacroF1", "F1"),
        "solver_diagnostics": solver_diag,
    }
    for k in common_solver_keys:
        quad[k] = solver_diag.get(k)

    original = {
        "test_top1_acc": _metric_from_table(report_truth_test, "Original", "ACC", "Top1", "Top-1"),
        "test_top5_acc": _metric_from_table(report_truth_test, "Original", "Top5", "Top-5"),
    }

    record = {
        "key": key,
        "hidden_dim": hidden_dim,
        "pool_fraction": pool_fraction,
        "rep_fit_size": rep_fit_size,
        "original": original,
        "quad4fhe": quad,
        "report_vs_ground_truth_test": report_truth_test,
        "report_vs_pseudo_labels_test": report_pseudo_test,
        "report_vs_ground_truth_records": _dataframe_records(getattr(result, "report_vs_truth", None)),
        "report_vs_pseudo_labels_records": _dataframe_records(getattr(result, "report_vs_pseudo", None)),
    }
    if extra:
        record.update(_to_jsonable(extra))
    return _to_jsonable(record)


def _collect_autosave_config() -> Dict[str, Any]:
    keys = [
        "SEED", "HIDDEN_DIMS", "HIDDEN_DIM", "EPOCHS", "LR", "BATCH_SIZE", "WEIGHT_DECAY",
        "TRAIN_SIZE", "VAL_SIZE", "TEST_SIZE", "TRAIN_NET_SIZE", "VAL_NET_SIZE",
        "MLP_VAL_FRACTION", "POOL_SIZES_TO_COMPARE", "REPLACEMENT_SELECTION_FRACTION",
        "MIN_POOL_SAMPLES", "MIN_SAMPLES_PER_CLASS", "MIN_PRESENT_CLASSES",
        "NUM_CLASSES", "FIT_SUBSAMPLE_PER_CLASS", "PCA_COMPONENTS", "SVD_COMPONENTS",
        "TFIDF_MAX_FEATURES", "TFIDF_NGRAM_RANGE", "BASELINES", "FLIP_LABELS",
        "USE_HF_DATASETS", "SHUTTLE_SOURCE",
    ]
    g = globals()
    return {k: _to_jsonable(g[k]) for k in keys if k in g}


def _make_autosave_payload() -> Dict[str, Any]:
    g = globals()
    return {
        "dataset": g.get("DATASET_NAME"),
        "experiment": g.get("EXPERIMENT_NAME"),
        "created_at": datetime.now().isoformat(timespec="seconds"),
        "source_notebook": g.get("SOURCE_NOTEBOOK", None),
        "log_file": str(g.get("LOG_PATH")),
        "seed": g.get("SEED", None),
        "dataset_info": {},
        "config": _collect_autosave_config(),
        "runs": [],
    }


def _ensure_autosave_payload() -> Dict[str, Any]:
    global _AUTOSAVE_PAYLOAD
    if _AUTOSAVE_PAYLOAD is None:
        _AUTOSAVE_PAYLOAD = _make_autosave_payload()
    return _AUTOSAVE_PAYLOAD


def _infer_dataset_info_from_runs(payload: Dict[str, Any]) -> Dict[str, Any]:
    info = dict(payload.get("dataset_info", {}) or {})
    runs = payload.get("runs", [])
    if runs:
        q0 = runs[0].get("quad4fhe", {})
        info.setdefault("calib_n_first", q0.get("calib_n"))
        info.setdefault("test_n", q0.get("test_n"))
        if "NUM_CLASSES" in globals():
            info.setdefault("num_classes", globals().get("NUM_CLASSES"))
        if "PCA_COMPONENTS" in globals():
            info.setdefault("input_dim", globals().get("PCA_COMPONENTS"))
        elif "SVD_COMPONENTS" in globals():
            info.setdefault("input_dim", globals().get("SVD_COMPONENTS"))
    return _to_jsonable(info)


def _summary_row_from_record(record: Dict[str, Any]) -> Dict[str, Any]:
    q = record.get("quad4fhe", {})
    return {
        "key": record.get("key"),
        "hidden_dim": record.get("hidden_dim"),
        "pool_fraction": record.get("pool_fraction"),
        "rep_fit_size": record.get("rep_fit_size"),
        "status": record.get("status", "ok"),
        "method_used": q.get("method_used"),
        "hard_feasible": q.get("hard_feasible"),
        "alpha": q.get("alpha"),
        "beta": q.get("beta"),
        "eta": q.get("eta"),
        "empirical_margin": q.get("empirical_margin"),
        "normalized_margin": q.get("normalized_margin"),
        "quant_decimals": q.get("quant_decimals"),
        "calib_n": q.get("calib_n"),
        "calib_agreement": q.get("calib_agreement"),
        "calib_mismatch_count": q.get("calib_mismatch_count"),
        "exact_preserved_on_calib": q.get("exact_preserved_on_calib"),
        "test_agreement": q.get("test_agreement"),
        "test_mismatch_count": q.get("test_mismatch_count"),
        "calib_test_agreement_gap": q.get("calib_test_agreement_gap"),
        "num_pairwise_constraints": q.get("num_pairwise_constraints"),
        "min_pairwise_margin": q.get("min_pairwise_margin"),
        "slack_positive_count": q.get("slack_positive_count"),
        "sum_slack": q.get("sum_slack"),
        "max_slack": q.get("max_slack"),
        "selected_C": q.get("selected_C"),
        "constraint_version": q.get("constraint_version"),
        "test_top1_acc": q.get("test_top1_acc"),
        "test_top5_acc": q.get("test_top5_acc"),
        "he_artifact_dir": q.get("he_artifact_dir"),
        "skip_reason": record.get("skip_reason"),
    }


def _autosave_write_current_payload() -> None:
    payload = _ensure_autosave_payload()
    payload["dataset_info"] = _infer_dataset_info_from_runs(payload)
    payload["config"] = _collect_autosave_config()
    payload["summary"] = _AUTOSAVE_SUMMARY_ROWS
    if "JSON_PATH" in globals():
        _save_json(payload, globals()["JSON_PATH"])
    if "SUMMARY_CSV_PATH" in globals() and _AUTOSAVE_SUMMARY_ROWS:
        _save_csv(_AUTOSAVE_SUMMARY_ROWS, globals()["SUMMARY_CSV_PATH"])
    _autosave_write_combined_dataset_json()


def _autosave_write_combined_dataset_json() -> None:
    g = globals()
    dataset = g.get("DATASET_NAME")
    if not dataset:
        return
    root = Path("..") / "results" / dataset
    combined = {"dataset": dataset, "created_at": datetime.now().isoformat(timespec="seconds")}
    found = False
    for exp in ("fulltrain", "smallpool"):
        p = root / exp / f"{dataset}_{exp}_results.json"
        if not p.exists():
            continue
        try:
            with p.open("r", encoding="utf-8") as fh:
                block = json.load(fh)
            combined[exp] = {
                "source_json": str(p),
                "source_notebook": block.get("source_notebook"),
                "log_file": block.get("log_file"),
                "dataset_info": block.get("dataset_info", {}),
                "config": block.get("config", {}),
                "runs": block.get("runs", []),
                "summary": block.get("summary", []),
            }
            found = True
        except Exception as exc:
            combined[f"{exp}_read_error"] = str(exc)
    if found:
        _save_json(combined, root / f"{dataset}_results.json")


def _autosave_record_result(
    *,
    result: Any,
    key: str,
    hidden_dim: Optional[int],
    fit_n: Optional[int],
    test_n: Optional[int],
    pool_fraction: Optional[float] = None,
    rep_fit_size: Optional[int] = None,
    extra: Optional[Dict[str, Any]] = None,
) -> Dict[str, Any]:
    payload = _ensure_autosave_payload()
    record = _build_quad4fhe_run_record(
        result=result,
        key=key,
        hidden_dim=hidden_dim,
        fit_n=fit_n,
        test_n=test_n,
        pool_fraction=pool_fraction,
        rep_fit_size=rep_fit_size,
        extra=extra,
    )
    payload["runs"].append(record)
    _AUTOSAVE_SUMMARY_ROWS.append(_summary_row_from_record(record))
    _autosave_write_current_payload()
    return record


def _autosave_record_skipped(
    *,
    key: str,
    hidden_dim: Optional[int],
    pool_fraction: Optional[float],
    reason: str,
    rep_fit_size: Optional[int] = None,
) -> Dict[str, Any]:
    payload = _ensure_autosave_payload()
    record = {
        "key": key,
        "hidden_dim": hidden_dim,
        "pool_fraction": pool_fraction,
        "rep_fit_size": rep_fit_size,
        "status": "skipped",
        "skip_reason": reason,
        "quad4fhe": {"status": "skipped", "skip_reason": reason},
    }
    payload["runs"].append(_to_jsonable(record))
    _AUTOSAVE_SUMMARY_ROWS.append(_summary_row_from_record(record))
    _autosave_write_current_payload()
    return record


def run_notebook_main_with_autosave(main_fn, log_path):
    global _AUTOSAVE_PAYLOAD, _AUTOSAVE_RUNS, _AUTOSAVE_SUMMARY_ROWS
    _AUTOSAVE_PAYLOAD = None
    _AUTOSAVE_RUNS = []
    _AUTOSAVE_SUMMARY_ROWS = []
    Path(log_path).parent.mkdir(parents=True, exist_ok=True)
    try:
        with tee_stdout_stderr(log_path):
            print(f"[autosave] dataset={globals().get('DATASET_NAME')} experiment={globals().get('EXPERIMENT_NAME')}")
            print(f"[autosave] output_dir={globals().get('OUTPUT_DIR')}")
            main_fn()
            _autosave_write_current_payload()
    except Exception:
        # Write partial JSON before re-raising, useful for debugging interrupted runs.
        err = traceback.format_exc()
        payload = _ensure_autosave_payload()
        payload["error"] = err
        if "JSON_PATH" in globals():
            _save_json(payload, globals()["JSON_PATH"])
        raise

# %%
import os
import random
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import quad4fhe


# ============================================================
# Autosave configuration
# ============================================================
from pathlib import Path
DATASET_NAME = "Shuttle"
EXPERIMENT_NAME = "smallpool"
SOURCE_NOTEBOOK = "Shuttle_smallpool_autosave.ipynb"
OUTPUT_DIR = Path("..") / "results" / DATASET_NAME / EXPERIMENT_NAME
LOG_PATH = OUTPUT_DIR / f"{DATASET_NAME}_{EXPERIMENT_NAME}_result.txt"
JSON_PATH = OUTPUT_DIR / f"{DATASET_NAME}_{EXPERIMENT_NAME}_results.json"
SUMMARY_CSV_PATH = OUTPUT_DIR / f"{DATASET_NAME}_{EXPERIMENT_NAME}_summary.csv"

from pathlib import Path


# ============================================================
# Configuration
# ============================================================
SEED = 2026
HIDDEN_DIM = 256
EPOCHS = 200
LR = 1e-3
BATCH_SIZE = 512

EARLY_STOP_PATIENCE = 10
EARLY_STOP_MIN_DELTA = 1e-4
WEIGHT_DECAY = 1e-5

TEST_SIZE = 0.20
TRAIN_NET_SIZE = 0.50
VAL_NET_SIZE = 0.10
REPLACEMENT_SELECTION_FRACTION = 0.5

POOL_SIZES_TO_COMPARE = [0.01, 0.05, 0.10, 0.20]

# Shuttle has ~58k samples, so 1% ≈ 580 samples.
# BUT: Shuttle is heavily imbalanced (Class 1 dominates, some classes < 50 total).
# The guards below may cause the smallest pools to be skipped.
MIN_POOL_SAMPLES = 50
MIN_PRESENT_CLASSES = 2

# ---------- Shuttle dataset loader configuration ----------
SHUTTLE_SOURCE = "openml"              # "file" or "openml"
SHUTTLE_TRAIN_FILE = "shuttle.trn"
SHUTTLE_TEST_FILE  = "shuttle.tst"
SHUTTLE_CSV        = "shuttle.csv"

NUM_CLASSES = 7

BASELINES = ["square", "ls_poly_2", "ls_poly_3", "ls_poly_5", "ls_poly_7",
             "remez_2", "remez_3", "remez_5", "remez_7",
             "ola", "precise_a11"]


# ============================================================
# Model + EarlyStopping
# ============================================================
class MulticlassMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_classes):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.bn  = nn.BatchNorm1d(hidden_dim)
        self.act = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        return self.fc2(self.act(self.bn(self.fc1(x))))


class EarlyStopping:
    def __init__(self, patience=EARLY_STOP_PATIENCE, min_delta=EARLY_STOP_MIN_DELTA):
        self.patience, self.min_delta = patience, min_delta
        self.best_loss = float("inf"); self.counter = 0
        self.best_epoch = 0; self.best_state = None

    def step(self, val_loss, epoch, model):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss, self.counter, self.best_epoch = val_loss, 0, epoch
            self.best_state = {k: v.clone() for k, v in model.state_dict().items()}
        else:
            self.counter += 1
        return self.counter >= self.patience

    def restore(self, model):
        if self.best_state is not None:
            model.load_state_dict(self.best_state)


def train_mlp(X_tr, y_tr, X_va, y_va, input_dim, hidden_dim, num_classes):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = MulticlassMLP(input_dim, hidden_dim, num_classes).to(device)

    X_tr_t = torch.tensor(X_tr, dtype=torch.float32).to(device)
    y_tr_t = torch.tensor(y_tr, dtype=torch.long).to(device)
    X_va_t = torch.tensor(X_va, dtype=torch.float32).to(device)
    y_va_t = torch.tensor(y_va, dtype=torch.long).to(device)

    opt = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    ce = nn.CrossEntropyLoss()
    stopper = EarlyStopping()

    print(f"  Architecture: Linear({input_dim}->{hidden_dim}) -> BN({hidden_dim}) "
          f"-> ReLU -> Linear({hidden_dim}->{num_classes})")
    print(f"  Device={device}, epochs={EPOCHS}, batch_size={BATCH_SIZE}")

    n = X_tr_t.shape[0]
    for epoch in range(EPOCHS):
        model.train()
        perm = torch.randperm(n, device=device)
        for i in range(0, n, BATCH_SIZE):
            idx = perm[i:i + BATCH_SIZE]
            opt.zero_grad()
            ce(model(X_tr_t[idx]), y_tr_t[idx]).backward()
            opt.step()

        model.eval()
        with torch.no_grad():
            val_loss = ce(model(X_va_t), y_va_t).item()

        if (epoch + 1) % 20 == 0 or epoch == 0:
            print(f"    epoch {epoch+1:>4d}  val_loss={val_loss:.6f}")

        if stopper.step(val_loss, epoch + 1, model):
            print(f"  Early stopping @ epoch {epoch+1} "
                  f"(best={stopper.best_loss:.6f} @ {stopper.best_epoch})")
            stopper.restore(model)
            break
    else:
        stopper.restore(model)
    model.cpu(); model.eval()
    return model


# ============================================================
# Shuttle dataset loader
# ============================================================
SHUTTLE_CLASS_NAMES = {
    0: "Rad Flow", 1: "Fpv Close", 2: "Fpv Open", 3: "High",
    4: "Bypass",   5: "Bpv Close", 6: "Bpv Open",
}

def load_shuttle():
    X, y = None, None

    if SHUTTLE_SOURCE == "file":
        if os.path.exists(SHUTTLE_TRAIN_FILE):
            print(f"Loading Shuttle from {SHUTTLE_TRAIN_FILE}", end="")
            df_train = pd.read_csv(SHUTTLE_TRAIN_FILE, header=None, sep=r"\s+")
            X_train = df_train.iloc[:, :-1].values.astype(np.float64)
            y_train = df_train.iloc[:, -1].values.astype(int)
            if os.path.exists(SHUTTLE_TEST_FILE):
                print(f" + {SHUTTLE_TEST_FILE}")
                df_test = pd.read_csv(SHUTTLE_TEST_FILE, header=None, sep=r"\s+")
                X_test = df_test.iloc[:, :-1].values.astype(np.float64)
                y_test = df_test.iloc[:, -1].values.astype(int)
                X = np.vstack([X_train, X_test])
                y = np.concatenate([y_train, y_test])
            else:
                print()
                X, y = X_train, y_train
        elif os.path.exists(SHUTTLE_CSV):
            print(f"Loading Shuttle from {SHUTTLE_CSV}")
            df = pd.read_csv(SHUTTLE_CSV)
            if df.columns[0].replace(".", "", 1).replace("-", "", 1).isdigit():
                df = pd.read_csv(SHUTTLE_CSV, header=None)
            X = df.iloc[:, :-1].values.astype(np.float64)
            y = df.iloc[:, -1].values.astype(int)
        else:
            raise FileNotFoundError(
                f"SHUTTLE_SOURCE='file' but neither {SHUTTLE_TRAIN_FILE} nor {SHUTTLE_CSV} found.\n"
                f"Download from https://archive.ics.uci.edu/dataset/148/statlog+shuttle "
                f"or set SHUTTLE_SOURCE='openml'.")
    elif SHUTTLE_SOURCE == "openml":
        print("Fetching Shuttle from OpenML (id=40685) ...")
        from sklearn.datasets import fetch_openml
        bunch = fetch_openml(data_id=40685, as_frame=False, parser="auto")
        X = bunch.data.astype(np.float64)
        y = np.asarray(bunch.target).astype(int)
    else:
        raise ValueError(f"Unknown SHUTTLE_SOURCE='{SHUTTLE_SOURCE}'.")

    if y.min() >= 1:
        y = y - 1

    num_classes = int(y.max() + 1)
    print(f"Shuttle classes ({num_classes}): {SHUTTLE_CLASS_NAMES}")
    print(f"Total samples: {len(X)}, Features: {X.shape[1]}")
    uniq, cnt = np.unique(y, return_counts=True)
    print(f"Class distribution: {dict(zip(uniq.tolist(), cnt.tolist()))}")
    return X, y, num_classes


# ============================================================
# Fixed-ratio split with variable pool
# ============================================================
def split_dataset_fixed(X, y, pool_frac):
    """
    Returns a dict of splits, OR None if the pool is too small
    (stratify would fail somewhere along the chain).
    """
    try:
        X_rest, X_test, y_rest, y_test = train_test_split(
            X, y, test_size=TEST_SIZE, random_state=SEED, stratify=y)

        val_frac_in_rest = VAL_NET_SIZE / (1.0 - TEST_SIZE)
        X_rest2, X_val_net, y_rest2, y_val_net = train_test_split(
            X_rest, y_rest, test_size=val_frac_in_rest,
            random_state=SEED + 1, stratify=y_rest)

        train_frac_in_rest2 = TRAIN_NET_SIZE / (1.0 - TEST_SIZE - VAL_NET_SIZE)
        X_train_net, X_pool_max, y_train_net, y_pool_max = train_test_split(
            X_rest2, y_rest2, test_size=1.0 - train_frac_in_rest2,
            random_state=SEED + 2, stratify=y_rest2)

        max_pool_frac = 1.0 - TEST_SIZE - VAL_NET_SIZE - TRAIN_NET_SIZE
        if pool_frac >= max_pool_frac - 1e-6:
            X_pool, y_pool = X_pool_max, y_pool_max
        else:
            keep = pool_frac / max_pool_frac
            # Subsampling: try stratified first; fall back to random.
            try:
                X_pool, _, y_pool, _ = train_test_split(
                    X_pool_max, y_pool_max, train_size=keep,
                    random_state=SEED + 3, stratify=y_pool_max)
            except ValueError:
                X_pool, _, y_pool, _ = train_test_split(
                    X_pool_max, y_pool_max, train_size=keep,
                    random_state=SEED + 3, stratify=None)

        # rep_fit / rep_sel split: same fallback.
        try:
            X_rep_fit, X_rep_sel, y_rep_fit, y_rep_sel = train_test_split(
                X_pool, y_pool, test_size=REPLACEMENT_SELECTION_FRACTION,
                random_state=SEED + 4, stratify=y_pool)
        except ValueError:
            X_rep_fit, X_rep_sel, y_rep_fit, y_rep_sel = train_test_split(
                X_pool, y_pool, test_size=REPLACEMENT_SELECTION_FRACTION,
                random_state=SEED + 4, stratify=None)

        return {
            "train_net": (X_train_net, y_train_net),
            "val_net":   (X_val_net, y_val_net),
            "rep_fit":   (X_rep_fit, y_rep_fit),
            "rep_sel":   (X_rep_sel, y_rep_sel),
            "test":      (X_test, y_test),
        }
    except ValueError as e:
        # Some upstream stratified split failed (extreme class imbalance
        # combined with a very small pool). Signal "skip this pool".
        print(f"  [split failed: {e}]  will be skipped.")
        return None


def extract_test_metrics(result, method_name):
    if result.report_vs_truth is None:
        return None
    df = result.report_vs_truth
    row = df[(df["Method"] == method_name) & (df["Split"] == "test")]
    if len(row) == 0:
        return None
    return row.iloc[0].to_dict()


# ============================================================
# Main
# ============================================================
def main():
    random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)

    print("\n" + "=" * 78)
    print("Step 1: Load Shuttle dataset")
    print("=" * 78)
    X_all, y_all, num_classes = load_shuttle()
    assert num_classes == NUM_CLASSES, \
        f"Expected {NUM_CLASSES} classes, found {num_classes}."
    d = X_all.shape[1]

    print(f"\nFixed splits: train_net={TRAIN_NET_SIZE*100:.0f}%, "
          f"val_net={VAL_NET_SIZE*100:.0f}%, test={TEST_SIZE*100:.0f}%")
    print(f"Pool sizes: {[f'{p*100:.0f}%' for p in POOL_SIZES_TO_COMPARE]}")

    print("\n" + "=" * 78)
    print("Step 2: Create fixed splits")
    print("=" * 78)
    max_pool = max(POOL_SIZES_TO_COMPARE)
    splits = split_dataset_fixed(X_all, y_all, pool_frac=max_pool)

    X_train_net_raw, y_train_net = splits["train_net"]
    X_val_net_raw,   y_val_net   = splits["val_net"]
    X_test_raw,      y_test      = splits["test"]

    scaler = StandardScaler().fit(X_train_net_raw)
    X_train_net = scaler.transform(X_train_net_raw).astype(np.float64)
    X_val_net   = scaler.transform(X_val_net_raw).astype(np.float64)
    X_test      = scaler.transform(X_test_raw).astype(np.float64)

    for key in ["train_net", "val_net", "rep_fit", "rep_sel", "test"]:
        Xi, _ = splits[key]
        print(f"  {key:12s}: n={len(Xi):6d}")

    print("\n" + "=" * 78)
    print("Step 3: Train MLP once")
    print("=" * 78)
    model = train_mlp(X_train_net, y_train_net, X_val_net, y_val_net,
                      d, HIDDEN_DIM, NUM_CLASSES)

    with torch.no_grad():
        logits_test = model(torch.tensor(X_test, dtype=torch.float32)).cpu().numpy()
    orig_acc = float(np.mean(logits_test.argmax(axis=1) == y_test))
    print(f"\n  Original model test top-1 ACC = {orig_acc:.4f}")

    print("\n" + "=" * 78)
    print("Step 4: quad4fhe.replace(...) per pool size")
    print("=" * 78)
    all_pool_results = {}

    for pool_frac in POOL_SIZES_TO_COMPARE:
        print("\n" + "-" * 78)
        print(f"POOL = {pool_frac*100:.0f}%")
        print("-" * 78)

        splits_p = split_dataset_fixed(X_all, y_all, pool_frac=pool_frac)
        if splits_p is None:
            print(f"  [SKIPPED] split produced no valid pool (too small / imbalanced)")
            all_pool_results[pool_frac] = None
            _autosave_record_skipped(
                key=f"pool={int(pool_frac*100):02d}%",
                hidden_dim=HIDDEN_DIM,
                pool_fraction=pool_frac,
                rep_fit_size=None,
                reason="skipped by notebook guard (too small, missing class, or invalid stratified split)",
            )
            continue

        X_rep_fit_raw, y_rep_fit = splits_p["rep_fit"]

        if len(X_rep_fit_raw) < MIN_POOL_SAMPLES:
            print(f"  [SKIPPED] rep_fit too small (n={len(X_rep_fit_raw)} "
                  f"< MIN_POOL_SAMPLES={MIN_POOL_SAMPLES})")
            all_pool_results[pool_frac] = None
            _autosave_record_skipped(
                key=f"pool={int(pool_frac*100):02d}%",
                hidden_dim=HIDDEN_DIM,
                pool_fraction=pool_frac,
                rep_fit_size=None,
                reason="skipped by notebook guard (too small, missing class, or invalid stratified split)",
            )
            continue

        counts = np.bincount(y_rep_fit, minlength=NUM_CLASSES)
        present_classes = int(np.sum(counts > 0))
        missing_classes = [i for i, c in enumerate(counts) if c == 0]

        if present_classes < MIN_PRESENT_CLASSES:
            print(f"  [SKIPPED] rep_fit covers only {present_classes} class(es) "
                  f"(need >= {MIN_PRESENT_CLASSES}). Counts: {counts.tolist()}")
            all_pool_results[pool_frac] = None
            _autosave_record_skipped(
                key=f"pool={int(pool_frac*100):02d}%",
                hidden_dim=HIDDEN_DIM,
                pool_fraction=pool_frac,
                rep_fit_size=None,
                reason="skipped by notebook guard (too small, missing class, or invalid stratified split)",
            )
            continue

        X_rep_fit = scaler.transform(X_rep_fit_raw).astype(np.float64)
        if missing_classes:
            print(f"  rep_fit: n={len(X_rep_fit)}, present={present_classes}/{NUM_CLASSES}, "
                  f"missing classes: {missing_classes}, counts: {counts.tolist()}")
        else:
            print(f"  rep_fit: n={len(X_rep_fit)}, per-class counts: {counts.tolist()}")

        result = quad4fhe.replace(
            task              = "multiclass",
            model             = model,
            hidden_layer      = "fc1",
            output_layer      = "fc2",
            activation        = "relu",
            fit_data          = (X_rep_fit, y_rep_fit),
            test_data         = (X_test, y_test),
            baselines         = BASELINES,
            export_he_dir     = f"he_artifacts_shuttle_pool_{int(pool_frac*100):02d}",
            use_cutting_plane = False,
            use_osqp_warmstart= False,
            verbose           = True,
            seed              = SEED,
        )
        all_pool_results[pool_frac] = result

        _autosave_record_result(
            result=result,
            key=f"pool={int(pool_frac*100):02d}%",
            hidden_dim=HIDDEN_DIM,
            fit_n=len(X_rep_fit),
            test_n=len(X_test),
            pool_fraction=pool_frac,
            rep_fit_size=len(X_rep_fit),
            extra={"pool": f"{int(pool_frac*100):02d}%"},
        )

        print(f"  method_used={result.method_used}, "
              f"hard_feasible={result.feasible}, "
              f"quant_decimals={result.quant_decimals}")
        q4 = extract_test_metrics(result, "Quad4FHE")
        if q4 is not None:
            acc = q4.get("ACC",       float("nan"))
            f1m = q4.get("MacroF1",   float("nan"))
            agr = q4.get("Agreement", float("nan"))
            print(f"  Quad4FHE test ACC={acc:.4f}  MacroF1={f1m:.4f}  Agreement={agr:.4f}")

    # --- Cross-pool tables ---
    print("\n" + "=" * 78)
    print("Step 5: Cross-pool comparison tables")
    print("=" * 78)

    method_order = ["Original", "Quad4FHE"] + BASELINES
    pool_labels = [f"{int(p*100):02d}%" for p in POOL_SIZES_TO_COMPARE]

    first_result = next((r for r in all_pool_results.values() if r is not None), None)
    if first_result is not None and first_result.report_vs_truth is not None:
        available_cols = list(first_result.report_vs_truth.columns)
        print(f"  Report columns: {available_cols}")
    else:
        available_cols = []

    METRIC_KEYS = [c for c in ["ACC", "MacroF1", "MacroPrec", "MacroRec", "AUC_ovr", "Agreement"]
                   if c in available_cols]

    def _build_matrix(metric_key):
        data = {}
        for pf, lbl in zip(POOL_SIZES_TO_COMPARE, pool_labels):
            result = all_pool_results[pf]
            col = {}
            for m in method_order:
                if result is None:
                    col[m] = float("nan")
                else:
                    row = extract_test_metrics(result, m)
                    col[m] = row[metric_key] if row is not None else float("nan")
            data[f"pool={lbl}"] = col
        return pd.DataFrame(data)

    for metric_key in METRIC_KEYS:
        print(f"\n--- Table: Test {metric_key} (ACC/F1/etc. vs TRUE labels; Agreement vs original model) ---")
        df = _build_matrix(metric_key)
        with pd.option_context("display.float_format", "{:.4f}".format):
            print(df.to_string())

    print("\n--- Meta Table ---")
    meta_rows = []
    for pf, lbl in zip(POOL_SIZES_TO_COMPARE, pool_labels):
        r = all_pool_results[pf]
        if r is None:
            meta_rows.append({"pool": lbl, "status": "SKIPPED"})
            continue
        meta_rows.append({
            "pool":             lbl,
            "method_used":      r.method_used,
            "hard_feasible":    r.feasible,
            "empirical_margin": round(r.empirical_margin, 6),
            "norm_margin":      round(r.normalized_margin, 6),
            "quant_decimals":   r.quant_decimals,
            "he_export_dir":    os.path.basename(r.he_export_dir) if r.he_export_dir else None,
        })
    print(pd.DataFrame(meta_rows).to_string(index=False))

    print("\n" + "=" * 78)
    print("Done.")
    print("=" * 78)


if __name__ == "__main__":
    run_notebook_main_with_autosave(main, LOG_PATH)
# Out:
# [autosave] stdout/stderr log -> ..\results\Shuttle\smallpool\Shuttle_smallpool_result.txt
# [autosave] dataset=Shuttle experiment=smallpool
# [autosave] output_dir=..\results\Shuttle\smallpool
#
# ==============================================================================
# Step 1: Load Shuttle dataset
# ==============================================================================
# Fetching Shuttle from OpenML (id=40685) ...
# Shuttle classes (7): {0: 'Rad Flow', 1: 'Fpv Close', 2: 'Fpv Open', 3: 'High', 4: 'Bypass', 5: 'Bpv Close', 6: 'Bpv Open'}
# Total samples: 58000, Features: 9
# Class distribution: {0: 45586, 1: 50, 2: 171, 3: 8903, 4: 3267, 5: 10, 6: 13}
#
# Fixed splits: train_net=50%, val_net=10%, test=20%
# Pool sizes: ['1%', '5%', '10%', '20%']
#
# ==============================================================================
# Step 2: Create fixed splits
# ==============================================================================
#   train_net   : n= 28999
#   val_net     : n=  5800
#   rep_fit     : n=  5800
#   rep_sel     : n=  5801
#   test        : n= 11600
#
# ==============================================================================
# Step 3: Train MLP once
# ==============================================================================
#   Architecture: Linear(9->256) -> BN(256) -> ReLU -> Linear(256->7)
#   Device=cuda, epochs=200, batch_size=512
#     epoch    1  val_loss=0.244439
#     epoch   20  val_loss=0.033332
#     epoch   40  val_loss=0.021103
#     epoch   60  val_loss=0.017006
#   Early stopping @ epoch 78 (best=0.012916 @ 68)
#
#   Original model test top-1 ACC = 0.9974
#
# ==============================================================================
# Step 4: quad4fhe.replace(...) per pool size
# ==============================================================================
#
# ------------------------------------------------------------------------------
# POOL = 1%
# ------------------------------------------------------------------------------
#   rep_fit: n=290, present=4/7, missing classes: [1, 5, 6], counts: [228, 0, 1, 45, 16, 0, 0]
#
# ==============================================================================
# Step 1: Extract folded model weights
# ==============================================================================
# hidden_layer: Linear (in=9, out=256)
#   folded BatchNorm1d at 'bn' (num_features=256)
#   found activation ReLU at 'act' (will be replaced)
# output_layer: Linear (in=256, out=7)
# W1: (256, 9), b1: (256,)
# W2: (7, 256), b2: (7,), num_classes=7
#
# ==============================================================================
# Step 2: Ingest fit_data / test_data and compute original-model predictions
# ==============================================================================
# Original model on fit: 290 samples, class counts = [229, 0, 0, 45, 16]
#
# ==============================================================================
# Step 3: Build lifted representation and solve
# ==============================================================================
# Attempting multi-class hard-margin QP (Proposition 2.6(1)) ...
#   hard-margin infeasible (status=infeasible); falling back to soft-margin sweep.
# Running multi-class soft-margin sweep over C (scipy) ...
#   best C=100.0, min_margin=-1.414517, calib_agreement=0.996552, sum_slack=2.559302, status=optimal
#
# Result: alpha=+0.3110199512  beta=+1.0434009687  eta=+0.2279992522
#
# ==============================================================================
# Step 4: Quantization robustness scan (1..7 decimals)
# ==============================================================================
#   1dp  delta=0.0528113769  within_tol=False  sep_ok=False  gap=-1.958044
#   2dp  delta=0.0040755221  within_tol=False  sep_ok=False  gap=-1.307638
#   3dp  delta=0.0004014655  within_tol=False  sep_ok=False  gap=-1.395295
#   4dp  delta=0.0000199887  within_tol=False  sep_ok=False  gap=-1.397576
#   5dp  delta=0.0000012248  within_tol=False  sep_ok=False  gap=-1.397720
#   6dp  delta=0.0000002588  within_tol=False  sep_ok=False  gap=-1.397757
#   7dp  delta=0.0000000752  within_tol=False  sep_ok=False  gap=-1.397748
#   No decimal level preserved separation; quant_decimals = 0 (do not quantize).
#
# ==============================================================================
# Step 5: Build drop-in replaced model
# ==============================================================================
#   built (QuadraticActivation in place of original activation).
#
# ==============================================================================
# Step 6: Compute replacement and baseline logits
# ==============================================================================
# Fitting baseline 'square' ...
#   square: max_err=3.622492e+01, mean_err=1.028179e+01
# Fitting baseline 'ls_poly_2' ...
#   ls_poly_2: max_err=5.551779e-01, mean_err=1.817029e-01
# Fitting baseline 'ls_poly_3' ...
#   ls_poly_3: max_err=5.540418e-01, mean_err=1.811778e-01
# Fitting baseline 'ls_poly_5' ...
#   ls_poly_5: max_err=3.460442e-01, mean_err=8.745101e-02
# Fitting baseline 'ls_poly_7' ...
#   ls_poly_7: max_err=2.521560e-01, mean_err=5.269800e-02
# Fitting baseline 'remez_2' ...
#   remez_2: max_err=3.761265e-01, mean_err=2.275866e-01
# Fitting baseline 'remez_3' ...
#   remez_3: max_err=3.695508e-01, mean_err=2.252461e-01
# Fitting baseline 'remez_5' ...
#   remez_5: max_err=1.998322e-01, mean_err=1.247573e-01
# Fitting baseline 'remez_7' ...
#   remez_7: max_err=1.356744e-01, mean_err=8.536252e-02
# Fitting baseline 'ola' ...
#   ola: max_err=5.550195e-02, mean_err=4.301066e-03
# Fitting baseline 'precise_a11' ...
#   precise_a11: max_err=2.843107e-03, mean_err=4.037690e-04
#
# ==============================================================================
# Step 7: Build evaluation reports (vs pseudo-labels and vs truth)
# ==============================================================================
#
# --- Report vs pseudo-labels (agreement with original model) ---
#      Method Split    ACC  MacroF1  MacroPrec  MacroRec  AUC_ovr  Agreement
#    Original   fit 1.0000   1.0000     1.0000    1.0000      NaN     1.0000
#    Original  test 1.0000   1.0000     1.0000    1.0000   1.0000     1.0000
#    Quad4FHE   fit 0.9966   0.9956     0.9928    0.9985      NaN     0.9966
#    Quad4FHE  test 0.9884   0.4795     0.5015    0.4687   0.7330     0.9884
#      square   fit 0.7414   0.4622     0.4855    0.4995      NaN     0.7414
#      square  test 0.7491   0.2682     0.2819    0.3627   0.4295     0.7491
#   ls_poly_2   fit 0.9310   0.8908     0.9732    0.8519      NaN     0.9310
#   ls_poly_2  test 0.9247   0.4419     0.5259    0.4063   0.7975     0.9247
#   ls_poly_3   fit 0.9310   0.8908     0.9732    0.8519      NaN     0.9310
#   ls_poly_3  test 0.9248   0.5630     0.6721    0.5078   0.8545     0.9248
#   ls_poly_5   fit 0.9379   0.9041     0.9757    0.8667      NaN     0.9379
#   ls_poly_5  test 0.9341   0.4493     0.4866    0.4281   0.7101     0.9341
#   ls_poly_7   fit 0.9724   0.9618     0.9887    0.9407      NaN     0.9724
#   ls_poly_7  test 0.9627   0.5728     0.5779    0.6227   0.7133     0.9627
#     remez_2   fit 0.9138   0.7886     0.9071    0.7208      NaN     0.9138
#     remez_2  test 0.9184   0.4972     0.6356    0.4438   0.7995     0.9184
#     remez_3   fit 0.9241   0.8433     0.9327    0.7833      NaN     0.9241
#     remez_3  test 0.9227   0.5049     0.6407    0.4539   0.8011     0.9227
#     remez_5   fit 0.9793   0.9719     0.9915    0.9556      NaN     0.9793
#     remez_5  test 0.9709   0.4639     0.4832    0.4493   0.7128     0.9709
#     remez_7   fit 1.0000   1.0000     1.0000    1.0000      NaN     1.0000
#     remez_7  test 0.9940   0.5987     0.6146    0.6260   0.7134     0.9940
#         ola   fit 1.0000   1.0000     1.0000    1.0000      NaN     1.0000
#         ola  test 0.9934   0.5905     0.5566    0.6959   0.7032     0.9934
# precise_a11   fit 1.0000   1.0000     1.0000    1.0000      NaN     1.0000
# precise_a11  test 0.9999   1.0000     0.9999    1.0000   1.0000     0.9999
#
# --- Report vs ground truth ---
#      Method Split    ACC  MacroF1  MacroPrec  MacroRec  AUC_ovr  Agreement
#    Original   fit 0.9966   0.7495     0.7489    0.7500      NaN     1.0000
#    Original  test 0.9974   0.7867     0.8932    0.8201   0.9991     1.0000
#    Quad4FHE   fit 0.9931   0.7462     0.7435    0.7489      NaN     0.9966
#    Quad4FHE  test 0.9872   0.4633     0.5001    0.4523   0.7079     0.9884
#      square   fit 0.7448   0.4762     0.4924    0.7504      NaN     0.7414
#      square  test 0.7486   0.2684     0.2815    0.3450   0.4923     0.7491
#   ls_poly_2   fit 0.9276   0.6676     0.7289    0.6389      NaN     0.9310
#   ls_poly_2  test 0.9240   0.4366     0.5564    0.3983   0.8299     0.9247
#   ls_poly_3   fit 0.9276   0.6676     0.7289    0.6389      NaN     0.9310
#   ls_poly_3  test 0.9240   0.5131     0.6279    0.4738   0.8297     0.9248
#   ls_poly_5   fit 0.9345   0.6775     0.7308    0.6500      NaN     0.9379
#   ls_poly_5  test 0.9331   0.4559     0.5330    0.4215   0.7049     0.9341
#   ls_poly_7   fit 0.9690   0.7208     0.7405    0.7056      NaN     0.9724
#   ls_poly_7  test 0.9614   0.5220     0.6239    0.4781   0.7103     0.9627
#     remez_2   fit 0.9103   0.5909     0.6793    0.5406      NaN     0.9138
#     remez_2  test 0.9173   0.5178     0.6344    0.4866   0.8398     0.9184
#     remez_3   fit 0.9207   0.6319     0.6985    0.5875      NaN     0.9241
#     remez_3  test 0.9216   0.5255     0.6394    0.4966   0.8406     0.9227
#     remez_5   fit 0.9759   0.7284     0.7426    0.7167      NaN     0.9793
#     remez_5  test 0.9698   0.4747     0.5537    0.4476   0.7091     0.9709
#     remez_7   fit 0.9966   0.7495     0.7489    0.7500      NaN     1.0000
#     remez_7  test 0.9926   0.5292     0.6845    0.4906   0.7105     0.9940
#         ola   fit 0.9966   0.7495     0.7489    0.7500      NaN     1.0000
#         ola  test 0.9917   0.5318     0.5549    0.5187   0.7025     0.9934
# precise_a11   fit 0.9966   0.7495     0.7489    0.7500      NaN     1.0000
# precise_a11  test 0.9973   0.7867     0.8931    0.8200   0.9991     0.9999
#
# ==============================================================================
# Step 8: Export HE artifacts to he_artifacts_shuttle_pool_01
# ==============================================================================
#   skipping baseline 'ola' from HE export (no plain-x polynomial representation).
#   skipping baseline 'precise_a11' from HE export (no plain-x polynomial representation).
# [HE] Exported artifacts -> he_artifacts_shuttle_pool_01/
#      task=multiclass, H=256, d=9, N_test=11600, schemes=10
#      - Quad4FHE        (name=quad4fhe, deg=2, thr=N/A)
#      - square          (name=square, deg=2, thr=N/A)
#      - ls_poly_2       (name=ls_poly_2, deg=2, thr=N/A)
#      - ls_poly_3       (name=ls_poly_3, deg=3, thr=N/A)
#      - ls_poly_5       (name=ls_poly_5, deg=5, thr=N/A)
#      - ls_poly_7       (name=ls_poly_7, deg=7, thr=N/A)
#      - remez_2         (name=remez_2, deg=2, thr=N/A)
#      - remez_3         (name=remez_3, deg=3, thr=N/A)
#      - remez_5         (name=remez_5, deg=5, thr=N/A)
#      - remez_7         (name=remez_7, deg=7, thr=N/A)
#
# ==== quad4fhe.ReplacementResult ====
#   method_used            = soft(C=100.0)
#   feasible (hard-margin) = False
#   alpha                  = +0.3110199512
#   beta                   = +1.0434009687
#   eta                    = +0.2279992522
#   empirical margin       = -1.4145169848
#   normalized margin      = -0.9344522024
#   constraint version     = multiclass_bias_free_dL_v1
#   min safe decimal places= 0  (not quantizable)
#   fit agreement         = 0.996552 (mismatches=1)
#   test agreement        = 0.988362 (mismatches=135)
#   HE artifact dir        = he_artifacts_shuttle_pool_01
# [autosave] JSON -> ..\results\Shuttle\smallpool\Shuttle_smallpool_results.json
# [autosave] CSV -> ..\results\Shuttle\smallpool\Shuttle_smallpool_summary.csv
# [autosave] JSON -> ..\results\Shuttle\Shuttle_results.json
#   method_used=soft(C=100.0), hard_feasible=False, quant_decimals=0
#   Quad4FHE test ACC=0.9872  MacroF1=0.4633  Agreement=0.9884
#
# ------------------------------------------------------------------------------
# POOL = 5%
# ------------------------------------------------------------------------------
#   rep_fit: n=1450, present=6/7, missing classes: [6], counts: [1149, 1, 6, 215, 78, 1, 0]
#
# ==============================================================================
# Step 1: Extract folded model weights
# ==============================================================================
# hidden_layer: Linear (in=9, out=256)
#   folded BatchNorm1d at 'bn' (num_features=256)
#   found activation ReLU at 'act' (will be replaced)
# output_layer: Linear (in=256, out=7)
# W1: (256, 9), b1: (256,)
# W2: (7, 256), b2: (7,), num_classes=7
#
# ==============================================================================
# Step 2: Ingest fit_data / test_data and compute original-model predictions
# ==============================================================================
# Original model on fit: 1450 samples, class counts = [1150, 0, 5, 217, 77, 1]
#
# ==============================================================================
# Step 3: Build lifted representation and solve
# ==============================================================================
# Attempting multi-class hard-margin QP (Proposition 2.6(1)) ...
#   hard-margin infeasible (status=infeasible); falling back to soft-margin sweep.
# Running multi-class soft-margin sweep over C (scipy) ...
#   best C=10.0, min_margin=-3.036616, calib_agreement=0.984138, sum_slack=54.683763, status=optimal
#
# Result: alpha=+0.0637798937  beta=+0.2334037372  eta=+0.0639217072
#
# ==============================================================================
# Step 4: Quantization robustness scan (1..7 decimals)
# ==============================================================================
#   1dp  delta=0.0610683958  within_tol=False  sep_ok=False  gap=-15.810242
#   2dp  delta=0.0064228351  within_tol=False  sep_ok=False  gap=-2.384185
#   3dp  delta=0.0004664550  within_tol=False  sep_ok=False  gap=-1.740677
#   4dp  delta=0.0000298234  within_tol=False  sep_ok=False  gap=-1.803509
#   5dp  delta=0.0000041100  within_tol=False  sep_ok=False  gap=-1.806405
#   6dp  delta=0.0000004075  within_tol=False  sep_ok=False  gap=-1.806593
#   7dp  delta=0.0000000384  within_tol=False  sep_ok=False  gap=-1.806601
#   No decimal level preserved separation; quant_decimals = 0 (do not quantize).
#
# ==============================================================================
# Step 5: Build drop-in replaced model
# ==============================================================================
#   built (QuadraticActivation in place of original activation).
#
# ==============================================================================
# Step 6: Compute replacement and baseline logits
# ==============================================================================
# Fitting baseline 'square' ...
#   square: max_err=1.510147e+03, mean_err=4.264383e+02
# Fitting baseline 'ls_poly_2' ...
#   ls_poly_2: max_err=3.421060e+00, mean_err=1.125627e+00
# Fitting baseline 'ls_poly_3' ...
#   ls_poly_3: max_err=3.235740e+00, mean_err=1.038046e+00
# Fitting baseline 'ls_poly_5' ...
#   ls_poly_5: max_err=1.994356e+00, mean_err=4.811817e-01
# Fitting baseline 'ls_poly_7' ...
#   ls_poly_7: max_err=1
#   ls_poly_7   fit 0.8455   0.3170     0.3050    0.3312      NaN     0.8462
#   ls_poly_7  test 0.8421   0.3017     0.4642    0.3033   0.8957     0.8427
#     remez_2   fit 0.8462   0.3186     0.3062    0.3333      NaN     0.8462
#     remez_2  test 0.8417   0.2720     0.4041    0.2847   0.9300     0.8425
#     remez_3   fit 0.8462   0.3186     0.3062    0.3333      NaN     0.8462
#     remez_3  test 0.8417   0.2719     0.4039    0.2847   0.9321     0.8425
#     remez_5   fit 0.8269   0.2882     0.3582    0.2787      NaN     0.8262
#     remez_5  test 0.8234   0.3125     0.3744    0.2995   0.8918     0.8240
#     remez_7   fit 0.8572   0.4933     0.6474    0.4542      NaN     0.8579
#     remez_7  test 0.8691   0.5403     0.7086    0.4823   0.8936     0.8691
#         ola   fit 0.9469   0.7377     0.8208    0.6934      NaN     0.9483
#         ola  test 0.9498   0.7083     0.9045    0.6454   0.9000     0.9512
# precise_a11   fit 0.9972   0.7860     0.7983    0.7756      NaN     1.0000
# precise_a11  test 0.9972   0.7866     0.8930    0.8200   0.9991     0.9998
#
# ==============================================================================
# Step 8: Export HE artifacts to he_artifacts_shuttle_pool_05
# ==============================================================================
#   skipping baseline 'ola' from HE export (no plain-x polynomial representation).
#   skipping baseline 'precise_a11' from HE export (no plain-x polynomial representation).
# [HE] Exported artifacts -> he_artifacts_shuttle_pool_05/
#      task=multiclass, H=256, d=9, N_test=11600, schemes=10
#      - Quad4FHE        (name=quad4fhe, deg=2, thr=N/A)
#      - square          (name=square, deg=2, thr=N/A)
#      - ls_poly_2       (name=ls_poly_2, deg=2, thr=N/A)
#      - ls_poly_3       (name=ls_poly_3, deg=3, thr=N/A)
#      - ls_poly_5       (name=ls_poly_5, deg=5, thr=N/A)
#      - ls_poly_7       (name=ls_poly_7, deg=7, thr=N/A)
#      - remez_2         (name=remez_2, deg=2, thr=N/A)
#      - remez_3         (name=remez_3, deg=3, thr=N/A)
#      - remez_5         (name=remez_5, deg=5, thr=N/A)
#      - remez_7         (name=remez_7, deg=7, thr=N/A)
#
# ==== quad4fhe.ReplacementResult ====
#   method_used            = soft(C=10.0)
#   feasible (hard-margin) = False
#   alpha                  = +0.0637798937
#   beta                   = +0.2334037372
#   eta                    = +0.0639217072
#   empirical margin       = -3.0366155520
#   normalized margin      = -1.7525553614
#   constraint version     = multiclass_bias_free_dL_v1
#   min safe decimal places= 0  (not quantizable)
#   fit agreement         = 0.984138 (mismatches=23)
#   test agreement        = 0.987759 (mismatches=142)
#   HE artifact dir        = he_artifacts_shuttle_pool_05
# [autosave] JSON -> ..\results\Shuttle\smallpool\Shuttle_smallpool_results.json
# [autosave] CSV -> ..\results\Shuttle\smallpool\Shuttle_smallpool_summary.csv
# [autosave] JSON -> ..\results\Shuttle\Shuttle_results.json
#   method_used=soft(C=10.0), hard_feasible=False, quant_decimals=0
#   Quad4FHE test ACC=0.9864  MacroF1=0.4605  Agreement=0.9878
#
# ------------------------------------------------------------------------------
# POOL = 10%
# ------------------------------------------------------------------------------
#   rep_fit: n=2900, present=6/7, missing classes: [5], counts: [2270, 3, 6, 458, 162, 0, 1]
#
# ==============================================================================
# Step 1: Extract folded model weights
# ==============================================================================
# hidden_layer: Linear (in=9, out=256)
#   folded BatchNorm1d at 'bn' (num_features=256)
#   found activation ReLU at 'act' (will be replaced)
# output_layer: Linear (in=256, out=7)
# W1: (256, 9), b1: (256,)
# W2: (7, 256), b2: (7,), num_classes=7
#
# ==============================================================================
# Step 2: Ingest fit_data / test_data and compute original-model predictions
# ==============================================================================
# Original model on fit: 2900 samples, class counts = [2272, 2, 5, 459, 160, 1, 1]
#
# ==============================================================================
# Step 3: Build lifted representation and solve
# ==============================================================================
# Attempting multi-class hard-margin QP (Proposition 2.6(1)) ...
#   hard-margin infeasible (status=infeasible); falling back to soft-margin sweep.
# Running multi-class soft-margin sweep over C (scipy) ...
#   best C=100.0, min_margin=-125.496879, calib_agreement=0.963793, sum_slack=436.915678, status=optimal
#
# Result: alpha=+0.0187526279  beta=+0.0790405786  eta=+0.0454244634
#
# ==============================================================================
# Step 4: Quantization robustness scan (1..7 decimals)
# ==============================================================================
#   1dp  delta=0.0534260262  within_tol=False  sep_ok=False  gap=-29.361563
#   2dp  delta=0.0048385909  within_tol=False  sep_ok=False  gap=-105.344049
#   3dp  delta=0.0004929592  within_tol=False  sep_ok=False  gap=-99.411894
#   4dp  delta=0.0000670015  within_tol=False  sep_ok=False  gap=-98.209444
#   5dp  delta=0.0000052118  within_tol=False  sep_ok=False  gap=-97.899002
#   6dp  delta=0.0000007285  within_tol=False  sep_ok=False  gap=-97.917014
#   7dp  delta=0.0000000507  within_tol=False  sep_ok=False  gap=-97.914687
#   No decimal level preserved separation; quant_decimals = 0 (do not quantize).
#
# ==============================================================================
# Step 5: Build drop-in replaced model
# ==============================================================================
#   built (QuadraticActivation in place of original activation).
#
# ==============================================================================
# Step 6: Compute replacement and baseline logits
# ==============================================================================
# Fitting baseline 'square' ...
#   square: max_err=4.449624e+03, mean_err=1.417360e+03
# Fitting baseline 'ls_poly_2' ...
#   ls_poly_2: max_err=6.149983e+00, mean_err=2.012604e+00
# Fitting baseline 'ls_poly_3' ...
#   ls_poly_3: max_err=6.136325e+00, mean_err=2.006303e+00
# Fitting baseline 'ls_poly_5' ...
#   ls_poly_5: max_err=3.832713e+00, mean_err=9.682756e-01
# Fitting baseline 'ls_poly_7' ...
#   ls_poly_7: max_err=2.792885e+00, mean_err=5.833960e-01
# Fitting baseline 'remez_2' ...
#   remez_2: max_err=4.169035e+00, mean_err=2.522169e+00
# Fitting baseline 'remez_3' ...
#   remez_3: max_err=4.093116e+00, mean_err=2.494749e+00
# Fitting baseline 'remez_5' ...
#   remez_5: max_err=2.213442e+00, mean_err=1.381845e+00
# Fitting baseline 'remez_7' ...
#   remez_7: max_err=1.502883e+00, mean_err=9.455526e-01
# Fitting baseline 'ola' ...
#   ola: max_err=1.360754e+06, mean_err=1.151011e+05
# Fitting baseline 'precise_a11' ...
#   precise_a11: max_err=3.150714e-02, mean_err=4.474381e-03
#
# ==============================================================================
# Step 7: Build evaluation reports (vs pseudo-labels and vs truth)
# ==============================================================================
#
# --- Report vs pseudo-labels (agreement with original model) ---
#      Method Split    ACC  MacroF1  MacroPrec  MacroRec  AUC_ovr  Agreement
#    Original   fit 1.0000   1.0000     1.0000    1.0000   1.0000     1.0000
#    Original  test 1.0000   1.0000     1.0000    1.0000   1.0000     1.0000
#    Quad4FHE   fit 0.
#     remez_3   fit 0.7831   0.1505     0.2972    0.1687      NaN     0.7834
#     remez_3  test 0.7862   0.1275     0.2552    0.1437   0.9107     0.7866
#     remez_5   fit 0.8376   0.2710     0.2604    0.2839      NaN     0.8390
#     remez_5  test 0.8416   0.2718     0.3322    0.2847   0.9327     0.8424
#     remez_7   fit 0.8152   0.3765     0.4024    0.3677      NaN     0.8166
#     remez_7  test 0.8235   0.3895     0.4791    0.3610   0.9376     0.8244
#         ola   fit 0.9355   0.6451     0.8177    0.5717      NaN     0.9355
#         ola  test 0.9340   0.4644     0.6845    0.4177   0.7653     0.9353
# precise_a11   fit 0.9969   0.8135     0.8552    0.7836      NaN     0.9983
# precise_a11  test 0.9964   0.8108     0.8922    0.8383   0.9991     0.9986
#
# ==============================================================================
# Step 8: Export HE artifacts to he_artifacts_shuttle_pool_10
# ==============================================================================
#   skipping baseline 'ola' from HE export (no plain-x polynomial representation).
#   skipping baseline 'precise_a11' from HE export (no plain-x polynomial representation).
# [HE] Exported artifacts -> he_artifacts_shuttle_pool_10/
#      task=multiclass, H=256, d=9, N_test=11600, schemes=10
#      - Quad4FHE        (name=quad4fhe, deg=2, thr=N/A)
#      - square          (name=square, deg=2, thr=N/A)
#      - ls_poly_2       (name=ls_poly_2, deg=2, thr=N/A)
#      - ls_poly_3       (name=ls_poly_3, deg=3, thr=N/A)
#      - ls_poly_5       (name=ls_poly_5, deg=5, thr=N/A)
#      - ls_poly_7       (name=ls_poly_7, deg=7, thr=N/A)
#      - remez_2         (name=remez_2, deg=2, thr=N/A)
#      - remez_3         (name=remez_3, deg=3, thr=N/A)
#      - remez_5         (name=remez_5, deg=5, thr=N/A)
#      - remez_7         (name=remez_7, deg=7, thr=N/A)
#
# ==== quad4fhe.ReplacementResult ====
#   method_used            = soft(C=100.0)
#   feasible (hard-margin) = False
#   alpha                  = +0.0187526279
#   beta                   = +0.0790405786
#   eta                    = +0.0454244634
#   empirical margin       = -125.4968788499
#   normalized margin      = -97.4935033069
#   constraint version     = multiclass_bias_free_dL_v1
#   min safe decimal places= 0  (not quantizable)
#   fit agreement         = 0.963793 (mismatches=105)
#   test agreement        = 0.963534 (mismatches=423)
#   HE artifact dir        = he_artifacts_shuttle_pool_10
# [autosave] JSON -> ..\results\Shuttle\smallpool\Shuttle_smallpool_results.json
# [autosave] CSV -> ..\results\Shuttle\smallpool\Shuttle_smallpool_summary.csv
# [autosave] JSON -> ..\results\Shuttle\Shuttle_results.json
#   method_used=soft(C=100.0), hard_feasible=False, quant_decimals=0
#   Quad4FHE test ACC=0.9622  MacroF1=0.4355  Agreement=0.9635
#
# ------------------------------------------------------------------------------
# POOL = 20%
# ------------------------------------------------------------------------------
#   rep_fit: n=5800, per-class counts: [4559, 5, 17, 890, 326, 1, 2]
#
# ==============================================================================
# Step 1: Extract folded model weights
# ==============================================================================
# hidden_layer: Linear (in=9, out=256)
#   folded BatchNorm1d at 'bn' (num_features=256)
#   found activation ReLU at 'act' (will be replaced)
# output_layer: Linear (in=256, out=7)
# W1: (256, 9), b1: (256,)
# W2: (7, 256), b2: (7,), num_classes=7
#
# ==============================================================================
# Step 2: Ingest fit_data / test_data and compute original-model predictions
# ==============================================================================
# Original model on fit: 5800 samples, class counts = [4562, 2, 15, 896, 321, 2, 2]
#
# ==============================================================================
# Step 3: Build lifted representation and solve
# ==============================================================================
# Attempting multi-class hard-margin QP (Proposition 2.6(1)) ...
#   hard-margin infeasible (status=infeasible); falling back to soft-margin sweep.
# Running multi-class soft-margin sweep over C (scipy) ...
#   best C=0.01, min_margin=-210.642050, calib_agreement=0.967069, sum_slack=788.821136, status=suboptimal(ABNORMAL_TERMINATION_IN_LNSRCH)
#
# Result: alpha=+0.0282888793  beta=+0.1131545422  eta=+0.0553586452
#
# ==============================================================================
# Step 4: Quantization robustness scan (1..7 decimals)
# ==============================================================================
#   1dp  delta=0.0544624020  within_tol=False  sep_ok=False  gap=-34.314145
#   2dp  delta=0.0058669622  within_tol=False  sep_ok=False  gap=-225.957365
#   3dp  delta=0.0004857581  within_tol=False  sep_ok=False  gap=-208.240173
#   4dp  delta=0.0000624524  within_tol=False  sep_ok=False  gap=-210.724906
#   5dp  delta=0.0000048707  within_tol=False  sep_ok=False  gap=-210.652684
#   6dp  delta=0.0000005917  within_tol=False  sep_ok=False  gap=-210.642957
#   7dp  delta=0.0000000652  within_tol=False  sep_ok=False  gap=-210.642235
#   No decimal level preserved separation; quant_decimals = 0 (do not quantize).
#
# ==============================================================================
# Step 5: Build drop-in replaced model
# ==============================================================================
#   built (QuadraticActivation in place of original activation).
#
# ==============================================================================
# Step 6: Compute replacement and baseline logits
# ==============================================================================
# Fitting baseline 'square' ...
#   square: max_err=5.064141e+04, mean_err=1.575690e+04
# Fitting baseline 'ls_poly_2' ...
#   ls_poly_2: max_err=2.046146e+01, mean_err=6.700923e+00
# Fitting baseline 'ls_poly_3' ...
#   ls_poly_3: max_err=2.026038e+01, mean_err=6.607769e+00
# Fitting baseline 'ls_poly_5' ...
#   ls_poly_5: max_err=1.262696e+01, mean_err=3.170216e+00
# Fitting baseline 'ls_poly_7' ...
#   ls_poly_7: max_err=9.181929e+00, mean_err=1.897606e+00
# Fitting baseline 'remez_2' ...
#   remez_2: max_err=1.409561e+01, mean_err=8.530499e+00
# Fitting baseline 'remez_3' ...
#   remez_3: max_err=1.354134e+01, mean_err=8.252920e+00
# Fitting baseline 'remez_5' ...
#   remez_5: max_err=7.313858e+00, mean_err=4.565949e+00
# Fitting baseline 'remez_7' ...
#   remez_7: max_err=4.960269e+00, mean_err=3.120799e+00
# Fitting baseline 'ola' ...
#   ola: max_err=2.067554e+07, mean_err=2.449317e+06
# Fitting baseline 'precise_a11' ...
#   precise_a11: max_err=1.065332e-01, mean_err=1.486809e-02
#
# ==============================================================================
# Step 7: Build evaluation reports (vs pseudo-labels and vs truth)
# ==============================================================================
#
# --- Report vs pseudo-labels (agreement with original model) ---
#      Method Split    ACC  MacroF1  MacroPrec  MacroRec  AUC_ovr  Agreement
#    Original   fit 1.0000   1.0000     1.0000    1.0000   1.0000     1.0000
#    Original  test 1.0000   1.0000     1.0000    1.0000   1.0000     1.0000
#    Quad4FHE   fit 0.9671   0.4548     0.5270    0.4303   0.7175     0.9671
#    Quad4FHE  test 0.9705   0.4707     0.5443    0.4425   0.7734     0.9705
#      square   fit 0.7548   0.2688     0.2832    0.3381   0.4138     0.7548
#      square  test 0.7491   0.2682     0.2819    0.3627   0.4295     0.7491
#   ls_poly_2   fit 0.7866   0.1258     0.1124    0.1429   0.8800     0.7866
#   ls_poly_2  test 0.7862   0.1258     0.1123    0.1429   0.8755     0.7862
#     remez_7   fit 0.7864   0.1275     0.2552    0.1437   0.9081     0.7866
#     remez_7  test 0.7863   0.1279     0.2552    0.1439   0.9049     0.7866
#         ola   fit 0.8790   0.4736     0.5531    0.4362   0.8875     0.8797
#         ola  test 0.8831   0.5054     0.5712    0.4705   0.8617     0.8831
# precise_a11   fit 0.9909   0.8929     0.9113    0.9137   0.9978     0.9928
# precise_a11  test 0.9878   0.7764     0.8784    0.8141   0.9986     0.9900
#
# ==============================================================================
# Step 8: Export HE artifacts to he_artifacts_shuttle_pool_20
# ==============================================================================
#   skipping baseline 'ola' from HE export (no plain-x polynomial representation).
#   skipping baseline 'precise_a11' from HE export (no plain-x polynomial representation).
# [HE] Exported artifacts -> he_artifacts_shuttle_pool_20/
#      task=multiclass, H=256, d=9, N_test=11600, schemes=10
#      - Quad4FHE        (name=quad4fhe, deg=2, thr=N/A)
#      - square          (name=square, deg=2, thr=N/A)
#      - ls_poly_2       (name=ls_poly_2, deg=2, thr=N/A)
#      - ls_poly_3       (name=ls_poly_3, deg=3, thr=N/A)
#      - ls_poly_5       (name=ls_poly_5, deg=5, thr=N/A)
#      - ls_poly_7       (name=ls_poly_7, deg=7, thr=N/A)
#      - remez_2         (name=remez_2, deg=2, thr=N/A)
#      - remez_3         (name=remez_3, deg=3, thr=N/A)
#      - remez_5         (name=remez_5, deg=5, thr=N/A)
#      - remez_7         (name=remez_7, deg=7, thr=N/A)
#
# ==== quad4fhe.ReplacementResult ====
#   method_used            = soft(C=0.01)
#   feasible (hard-margin) = False
#   alpha                  = +0.0282888793
#   beta                   = +0.1131545422
#   eta                    = +0.0553586452
#   empirical margin       = -210.6420503108
#   normalized margin      = -208.9081231745
#   constraint version     = multiclass_bias_free_dL_v1
#   min safe decimal places= 0  (not quantizable)
#   fit agreement         = 0.967069 (mismatches=191)
#   test agreement        = 0.970517 (mismatches=342)
#   HE artifact dir        = he_artifacts_shuttle_pool_20
# [autosave] JSON -> ..\results\Shuttle\smallpool\Shuttle_smallpool_results.json
# [autosave] CSV -> ..\results\Shuttle\smallpool\Shuttle_smallpool_summary.csv
# [autosave] JSON -> ..\results\Shuttle\Shuttle_results.json
#   method_used=soft(C=0.01), hard_feasible=False, quant_decimals=0
#   Quad4FHE test ACC=0.9691  MacroF1=0.4525  Agreement=0.9705
#
# ==============================================================================
# Step 5: Cross-pool comparison tables
# ==============================================================================
#   Report columns: ['Method', 'Split', 'ACC', 'MacroF1', 'MacroPrec', 'MacroRec', 'AUC_ovr', 'Agreement']
#
# --- Table: Test ACC (ACC/F1/etc. vs TRUE labels; Agreement vs original model) ---
#              pool=01%  pool=05%  pool=10%  pool=20%
# Original       0.9974    0.9974    0.9974    0.9974
# Quad4FHE       0.9872    0.9864    0.9622    0.9691
# square         0.7486    0.7486    0.7486    0.7486
# ls_poly_2      0.9240    0.8088    0.7862    0.7859
# ls_poly_3      0.9240    0.7899    0.7862    0.7859
# ls_poly_5      0.9331    0.8417    0.7864    0.7859
# ls_poly_7      0.9614    0.8421    0.8419    0.7859
# remez_2        0.9173    0.8417    0.7862    0.7859
# remez_3        0.9216    0.8417    0.7862    0.7859
# remez_5        0.9698    0.8234    0.8416    0.7861
# remez_7        0.9926    0.8691    0.8235    0.7863
# ola            0.9917    0.9498    0.9340    0.8831
# precise_a11    0.9973    0.9972    0.9964    0.9878
#
# --- Table: Test MacroF1 (ACC/F1/etc. vs TRUE labels; Agreement vs original model) ---
#              pool=01%  pool=05%  pool=10%  pool=20%
# Original       0.7867    0.7867    0.7867    0.7867
# Quad4FHE       0.4633    0.4605    0.4355    0.4525
# square         0.2684    0.2684    0.2684    0.2684
# ls_poly_2      0.4366    0.2103    0.1271    0.1257
# ls_poly_3      0.5131    0.1448    0.1271    0.1257
# ls_poly_5      0.4559    0.2716    0.1284    0.1257
# ls_poly_7      0.5220    0.3017    0.2723    0.1257
# remez_2        0.5178    0.2720    0.1275    0.1257
# remez_3        0.5255    0.2719    0.1275    0.1257
# remez_5        0.4747    0.3125    0.2718    0.1266
# remez_7        0.5292    0.5403    0.3895    0.1279
# ola            0.5318    0.7083    0.4644    0.5054
# precise_a11    0.7867    0.7866    0.8108    0.7764
#
# --- Table: Test MacroPrec (ACC/F1/etc. vs TRUE labels; Agreement vs original model) ---
#              pool=01%  pool=05%  pool=10%  pool=20%
# Original       0.8932    0.8932    0.8932    0.8932
# Quad4FHE       0.5001    0.5147    0.5332    0.5428
# square         0.2815    0.2815    0.2815    0.2815
# ls_poly_2      0.5564    0.2578    0.2552    0.1123
# ls_poly_3      0.6279    0.2556    0.2552    0.1123
# ls_poly_5      0.5330    0.2608    0.2348    0.1123
# ls_poly_7      0.6239    0.4642    0.4047    0.1123
# remez_2        0.6344    0.4041    0.2552    0.1123
# remez_3        0.6394    0.4039    0.2552    0.1123
# remez_5        0.5537    0.3744    0.3322    0.2552
# remez_7        0.6845    0.7086    0.4791    0.2552
# ola            0.5549    0.9045    0.6845    0.5712
# precise_a11    0.8931    0.8930    0.8922    0.8784
#
# --- Table: Test MacroRec (ACC/F1/etc. vs TRUE labels; Agreement vs original model) ---
#              pool=01%  pool=05%  pool=10%  pool=20%
# Original       0.8201    0.8201    0.8201    0.8201
# Quad4FHE       0.4523    0.4470    0.4135    0.4283
# square         0.3450    0.3450    0.3450    0.3450
# ls_poly_2      0.3983    0.2012    0.1435    0.1429
# ls_poly_3      0.4738    0.1529    0.1435    0.1429
# ls_poly_5      0.4215    0.2846    0.1442    0.1429
# ls_poly_7      0.4781    0.3033    0.2847    0.1429
# remez_2        0.4866    0.2847    0.1437    0.1429
# remez_3        0.4966    0.2847    0.1437    0.1429
# remez_5        0.4476    0.2995    0.2847    0.1433
# remez_7        0.4906    0.4823    0.3610    0.1439
# ola            0.5187    0.6454    0.4177    0.4705
# precise_a11    0.8200    0.8200    0.8383    0.8141
#
# --- Table: Test AUC_ovr (ACC/F1/etc. vs TRUE labels; Agreement vs original model) ---
#              pool=01%  pool=05%  pool=10%  pool=20%
# Original       0.9991    0.9991    0.9991    0.9991
# Quad4FHE       0.7079    0.7565    0.8478    0.7982
# square         0.4923    0.4923    0.4923    0.4923
# ls_poly_2      0.8299    0.9281    0.8868    0.8679
# ls_poly_3      0.8297    0.9307    0.8873    0.8679
# ls_poly_5      0.7049    0.9355    0.9224    0.8681
# ls_poly_7      0.7103    0.8957    0.9343    0.8683
# remez_2        0.8398    0.9300    0.9107    0.8680
# remez_3        0.8406    0.9321    0.9107    0.8680
# remez_5        0.7091    0.8918    0.9327    0.8838
# remez_7        0.7105    0.8936    0.9376    0.9049
# ola            0.7025    0.9000    0.7653    0.8617
# precise_a11    0.9991    0.9991    0.9991    0.9986
#
# --- Table: Test Agreement (ACC/F1/etc. vs TRUE labels; Agreement vs original model) ---
#              pool=01%  pool=05%  pool=10%  pool=20%
# Original       1.0000    1.0000    1.0000    1.0000
# Quad4FHE       0.9884    0.9878    0.9635    0.9705
# square         0.7491    0.7491    0.7491    0.7491
# ls_poly_2      0.9247    0.8093    0.7865    0.7862
# ls_poly_3      0.9248    0.7903    0.7865    0.7862
# ls_poly_5      0.9341    0.8422    0.7866    0.7862
# ls_poly_7      0.9627    0.8427    0.8422    0.7862
# remez_2        0.9184    0.8425    0.7866    0.7862
# remez_3        0.9227    0.8425    0.7866    0.7862
# remez_5        0.9709    0.8240    0.8424    0.7863
# remez_7        0.9940    0.8691    0.8244    0.7866
# ola            0.9934    0.9512    0.9353    0.8831
# precise_a11    0.9999    0.9998    0.9986    0.9900
#
# --- Meta Table ---
# pool   method_used  hard_feasible  empirical_margin  norm_margin  quant_decimals                he_export_dir
#  01% soft(C=100.0)          False         -1.414517    -0.934452               0 he_artifacts_shuttle_pool_01
#  05%  soft(C=10.0)          False         -3.036616    -1.752555               0 he_artifacts_shuttle_pool_05
#  10% soft(C=100.0)          False       -125.496879   -97.493503               0 he_artifacts_shuttle_pool_10
#  20%  soft(C=0.01)          False       -210.642050  -208.908123               0 he_artifacts_shuttle_pool_20
#
# ==============================================================================
# Done.
# ==============================================================================
# [autosave] JSON -> ..\results\Shuttle\smallpool\Shuttle_smallpool_results.json
# [autosave] CSV -> ..\results\Shuttle\smallpool\Shuttle_smallpool_summary.csv
# [autosave] JSON -> ..\results\Shuttle\Shuttle_results.json
